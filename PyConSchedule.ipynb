# %%
import yaml
from yaml.representer import SafeRepresenter
from math import isnan

# %%
import requests
from bs4 import BeautifulSoup
import pandas

# %%
class folded_str(str): pass

class literal_str(str): pass

def change_style(style, representer):
    def new_representer(dumper, data):
        scalar = representer(dumper, data)
        scalar.style = style
        return scalar
    return new_representer

# represent_str does handle some corner cases, so use that
# instead of calling represent_scalar directly
represent_folded_str = change_style('>', SafeRepresenter.represent_str)
represent_literal_str = change_style('|', SafeRepresenter.represent_str)

yaml.add_representer(folded_str, represent_folded_str)
yaml.add_representer(literal_str, represent_literal_str)

# %%
r = requests.get("https://th.pycon.org/en/talks/") 
soup = BeautifulSoup(r.content, "html.parser")
titles = list(map(lambda x: x.text,soup.find_all("h2")))
speakers = list(map(lambda x: x.find_next("p").text[3:],soup.find_all("h2")))
descriptions = list(map(lambda x: x.find_next("div",{"class":"section"}).find("p").text,soup.find_all("h2")))
print(titles)
print(speakers)
print(descriptions)

bio = {}
speakerimg = {}
r = requests.get("https://th.pycon.org/en/speakers/") 
soup = BeautifulSoup(r.content, "html.parser")
for h2tag in soup.find_all("h2"):
  name = h2tag.text.lower()
  biotag = h2tag.find_next("div",{"class":"section"})
  currbio = str(biotag.decode_contents()).replace("\u2019","'").replace("\u2013","").replace("<h3>Biography</h3>","").strip()
  bio[name] = currbio
  imgtag = h2tag.find_next("img")
  if imgtag: speakerimg[name] = imgtag["src"]

print(speakerimg)
print(bio)
# Out:
# ['Python made my dream come true', 'Kill the mutants, protect your code!', 'From 0 to Awesome: How we got Python to supercharge our ML stack', 'AIoT: Intelligence on Low Power Microcontroller, with MicroPython', 'Understanding and Implementing Generative Adversarial Networks (GANs): One of the BIGGEST Breakthroughs in the Deep Learning Revolution', 'Functional Programming in Python: Lessons from Haskell and Clojure', 'Demystifying Conversational AI with Python', 'How to build an open source catbot with Python, a 3D printer and a microcontroller', "How pyThaiNLP's thai2fit Outperforms Google's BERT: State-of-the-Art Thai Text Classification and Beyond", 'Understanding of distributed processing in Python', 'Interactive Python Dashboards with Plotly and Dash', 'When life gives you Orange, make data speak volumes!', 'Program Thinking - How do you design programs for diversity?', 'Security Issues on your Python Code', 'Python for Data Science Projects at Coraline', 'Marlin: A Smali to Python Transpiler for Android Hacking', 'E-commerce for Django', 'Machine Learning Democratization with Python', 'Designing and Building Serverless Machine Learning-powered Applications with Python', 'Advanced Google Colaboratory', 'Pyladies and Importance of community participation', 'Adding a GraphQL API to Django (with Vue.js frontend)', 'Python in Production Engineering @ Facebook', 'First steps in Deep Learning with TensorFlow 2.0 : CNNs', 'Securing your Python APIs with Auth0', 'Teaching Coding To Kids', 'Unlocking the power of natural language by machine translation: how python could serve my purpose?', 'Facial Keypoints Detection with PyTorch', 'Ready to say goodbye to Python 2.7 ! ?', 'Forklifting Django: Migrating A Complex Django App To Kubernetes', 'Raiden Network for instant crypto payment & lower fees', 'Fuzzy Multi-Criteria Portfolio Optimisation with Python (and maybe a little bit of Mathematica)', 'Hypothesis: Property-Based Testing for Python', 'Visualize the Black Box - An introduction to Interpretable Machine Learning', 'The Buzz about Bees', 'The Fastest Path to Deep Learning', 'Deep Learning Introductory Workshop with TensorFlow 2.0', 'Addressing class imbalance in Machine Learning', 'A resilient, scalable tracing and analysis system for micro-services - HayStack', 'Production-ize deep learning with PyTorch, RedisAI and Hangar', 'Python for beginners', 'Developing Natural Language Processing Applications Using Python', 'Automate the Boring Stuff with Slackbot', 'Unique ways to Hack into a Python Web Service', 'JWT authentication with Django', "Any Code Formatter You Like - As Long As It's Black"]
# ['AKSHAT SHARMA', 'Alex Khaerov', 'Amir Arad', 'Andri Yadi', 'Anmol Krishan Sachdeva', 'Anthony Khong', 'Avneet Kaur', 'Chanapai Chuadchum', 'Charin', 'Chie Hayashida', 'Doni Rubiagatra', 'Drishti Jain', 'Elisha Tan', 'Harley Davidson Karel', 'Jiranun Jiratrakanvong', 'Joe Chasinga', 'Jonghwa Seo', 'Jorge Torres', 'Joshua Arvin Lat', 'Korakot Chaovavanich', 'Lina KATAYOSE(selina)', 'Manuel Riel', 'Mark Hollow', 'Martin Andrews', 'Md Shahbaz Alam', 'Mishari Muqbil', 'Mohamed Ali SOLA (Dali SOLA)', 'Nithiroj Tripatarasit', 'Noah', 'Noah Kantrowitz', 'Pisuth Daengthongdee', 'Poomjai Nacaskul, PhD, DIC, CFA', 'Rae Knowler', 'Rahul Bhatia', 'Robert Owen', 'Sam Witteveen', 'Sam Witteveen + Martin Andrews', 'Sara Iris Garcia', 'Sarthak Deshwal', 'Sherin Thomas', 'Sudarat Chattanon', 'TUSHAR BANSAL', 'Takanori Suzuki', 'Tilak T', 'Viral Parmar', 'Zsolt Dollenstein']
# ['Python helped me fulfill my teenage dream to visit silicon valley before turning 20. I won an intercollege hackathon for building a Vision app using python, which got selected me for silicon valley and eminent Harvard Conf. A senior from my college inspired me, now, I wish to inspire novices.', "You definitely have unit tests. Your code coverage above 80 or 90? Are u still struggling with bugs and wanna increase the quality? What if I say that quarter of your units are non-viable mutants? Yes, it is true and sounds rude. Let's mutate your tests and look what it gets you.", 'Python is now a crucial foundation in our org, with its dynamicity, user friendliness, and community-backed frameworks complementing the firepower we already had from Scala.', "AI + IoT = AIoT is the latest advancement of AI and IoT. Let's move beyond buzzword and seeing it in action. This session will show how to use MicroPython superpower to make Machine Learning (ML) inference runs right on the low power Microcontroller (MCU), not in the cloud, to build AIoT application", "Generative Adversarial Networks are one of the latest advancements in Deep Learning. Interested in knowing how to generate content (images, music, and much more) instead of classifying one into categories? Let's dive into the details of GANs: One of the BIGGEST Breakthroughs in the DL Revolution.", 'In this talk, I argue that Python is not quite a functional programming language. We draw examples from Haskell and Clojure to highlight the importance of immutability, functional core and reusable data. We look into writing idiomatic Python, whilst enjoying the benefits of functional programming.', '“Ok Google, Tell me how do you work?” Have you ever wondered, what goes behind asking a voice assistant to perform a particular action to having the output being delivered to you? Using open source NLP libraries like NLTK, and Spacy, we will learn concepts that form the heart of conversational AI.', "This talk is about a project that was designed to test the ML A.I research and robotics opensource. The aim is to improve the robot's ability at human interaction and develop various applications for the robot. Right now this robot is an early protype with limited applications. This project aims to improve the robot's abilities in the near future.", "Google's TPU-trained BERT made the headlines when it claimed state-of-the-art text classification results in multiple languages, but not Thai. This is the story of how our rag-tag group of open-source coders managed to outperform Google with our very own Thai text classification model, thai2fit.", 'There are several ways and libraries for distributed processing using Python. We need to understand the concepts and features of these libraries for efficient usage of computing resources. In this session, I will discuss how to be good to choose and use these distributed processing libraries.', 'In the interactive visualization world mainly we hear about Tableau and Shiny for R. How about Python? Python’s visualization landscape is quite complex with many available libraries. In this talk, we will look for an easy and fun way to build an interactive dashboard using Plotly and Dash', 'Have you ever thought of using data visualization to represent data; but feel that it is a cumbersome process? Worry not – Orange is here to the rescue!\nCome, dive into the world of this magical open source data mining tool that can also be used as a Python library.\nBeginner friendly!', 'There’s much more we could do to improve gender diversity in tech. But with so many ideas, how should you get started in tackling this problem? How do you measure success? In this talk, I will share the people-centric methodology that helps you design your diversity programs and initiatives.', 'This topic will cover how to find security issue on python code using open source Static Analysis Security Testing. So that developer can found & fixed the security issue since on development stage, w ...
# {'akshat sharma': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/48515/IMG_20180907_122310.jpeg', 'alex khaerov': 'https://secure.gravatar.com/avatar/320f3b558c773592bba16c976d1b28d1?s=500', 'amir arad': 'https://secure.gravatar.com/avatar/7ebded1e9171acbf1b8cbf3532e25172?s=500', 'andri yadi': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/47721/RIOT_DSC1564_copy.JPG', 'anmol krishan sachdeva': 'https://secure.gravatar.com/avatar/0233f28830fe1e51ae0b7783e5838db6?s=500', 'anthony khong': 'https://secure.gravatar.com/avatar/62a12078cfba41bcd8d0886a7a7d3a20?s=500', 'avneet kaur': 'https://secure.gravatar.com/avatar/c4b633c794222b514d8881e5839da63a?s=500', 'chanapai chuadchum': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/45031/profile.jpg', 'charin': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/45031/profile.jpg', 'chie hayashida': 'https://secure.gravatar.com/avatar/7f7abff13e7c5ad15bfa3a823313ef9d?s=500', 'doni rubiagatra': 'https://secure.gravatar.com/avatar/eed0ef6cc8a0f435d5d8c9a5648f1551?s=500', 'drishti jain': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/36129/WhatsApp_Image_2019-04-21_at_8.52.00_PM.jpeg', 'elisha tan': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/15327/elisha-speaker_copy.png', 'harley davidson karel': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/28808/David.jpg', 'jiranun jiratrakanvong': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/45206/7566C8EA-E7E2-4867-B79A-094534D151DA.jpeg', 'joe chasinga': 'https://secure.gravatar.com/avatar/c06b54277a2961c3e0f735aa0c8d85f9?s=500', 'jonghwa seo': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/45418/pincoin-logo-A2.png', 'jorge torres': 'https://secure.gravatar.com/avatar/03886c577a1c4d30efa531b8f85aa80f?s=500', 'joshua arvin lat': 'https://secure.gravatar.com/avatar/e412f3f4cb20c7070822a6faebf656d1?s=500', 'korakot chaovavanich': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/25745/fullsizeoutput_b7.jpeg', 'lina katayose(selina)': 'https://secure.gravatar.com/avatar/442340722ced9c7c1bdf618ece413c69?s=500', 'manuel riel': 'https://secure.gravatar.com/avatar/24ba35029a2b10d0af542d213cfdaf3c?s=500', 'mark hollow': 'https://secure.gravatar.com/avatar/1f9b0b1483c7edc284513caeefa40fb1?s=500', 'martin andrews': 'https://secure.gravatar.com/avatar/eedd4ff31246cafae4a8ebbf08260159?s=500', 'md shahbaz alam': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/19104/mdsbzalam.jpg', 'mishari muqbil': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/27090/IMG-0002.JPG', 'mohamed ali sola (dali sola)': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/27090/IMG-0002.JPG', 'nithiroj tripatarasit': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/27090/IMG-0002.JPG', 'noah': 'https://secure.gravatar.com/avatar/f84b4128e61163fad7751e4dd8ebac50?s=500', 'noah kantrowitz': 'https://secure.gravatar.com/avatar/cf611565f0b79abd0b3dc200ad867661?s=500', 'pisuth daengthongdee': 'https://secure.gravatar.com/avatar/02db6091a997dc75b39fddfe6a740494?s=500', 'poomjai nacaskul, phd, dic, cfa': 'https://secure.gravatar.com/avatar/02ef5c925c1e92968925675e253a72cc?s=500', 'rae knowler': 'https://secure.gravatar.com/avatar/843df29a0383ee0094a5caa2defd8707?s=500', 'rahul bhatia': 'https://secure.gravatar.com/avatar/e16d4591c7f44180024093015eec7512?s=500', 'robert owen': 'https://secure.gravatar.com/avatar/3bd96a0518aafe7632c76cccabc3501d?s=500', 'sam witteveen': 'https://secure.gravatar.com/avatar/02da2ef8a441965087137c2691e39d34?s=500', 'sara iris garcia': 'https://secure.gravatar.com/avatar/da7607390ad88d1592247079d2381321?s=500', 'sarthak deshwal': 'https://secure.gravatar.com/avatar/ebb0ce50f3e93125e7f5fe4406a78723?s=500', 'sherin thomas': 'https://secure.gravatar.com/avatar/c32e9a85da547a9e81 ...
# {'akshat sharma': "<p>Hie, I'm Akshat, a Govt. of India recognized Silicon Valley fellow and a Harvard University Conference Scholar. Currently, I'm working on the problem of distracted driving and recently built an Android app (visit: inSessionApp.com) to manage my calls and acknowledging callers while I sleep. I've previously worked at a Thailand based and a California based company. This summers, I'm working with an India based startup as a Software Engineer. Above all this, I love to empower people in my connection.</p>", 'alex khaerov': '<p><strong>Alex Khaerov</strong> is a development lead at <a class="reference external" href="https://chainstack.com">Chainstack</a>, with 9+ years in web services development across diverse domains. His main passion is building robust, high-load and distributed service platforms on top of a multi-cloud environment, utilizing all the power of Python and cloud native services. An organized of <a class="reference external" href="https://conf.python.ru">Moscow Python Conf</a> and avid activist of <a class="reference external" href="http://pugs.org.sg/">Singapore Python User Group</a>, cloud native enthusiast and member of Kubernetes SG community. In his spare time, he speaks publicly at tech conferences and secretly codes in Python. Huge fan of laptop stickers.</p>', 'amir arad': '<p>Studied Math, building systems, loves traveling and puns.</p>', 'andri yadi': '<p>CEO of DycodeX - the AIoT enabler in Indonesia. Microsoft Most Valuable Professional (MVP) of Microsoft Azure. 15 years as entrepreneur. A developer, hardware maker, and public speaker.</p>', 'anmol krishan sachdeva': '<ul class="simple">\n<li>Currently, working as a Platform Software Engineer at Bigbasket, India (India\'s largest online food and grocery store).</li>\n<li>MSc in Advanced Computing (Machine Learning, Artifical Intelligence, Robotics, Cloud Computing, and Computational Neuroscience), University of Bristol, United Kingdom.</li>\n<li>International Tech Speaker (spoke at numerous National and International Conferences).</li>\n<li>Last year, gave a talk about "Recurrent Neural Networks and Long Short-Term Memory Networks (LSTMs)" at EuroPython, Edinburgh, Scotland - July 2018.\nLink: <a class="reference external" href="https://ep2018.europython.eu/conference/talks/understanding-and-implementing-recurrent-neural-networks-using-python">Recurrent Neural Networks and Long Short-Term Memory Networks</a>\n</li>\n<li>Last year, gave a talk about "Understanding and Implementing Recurrent Neural Networks using Python" at GeoPython, Basel, Switzerland - May 18.\nLink: <a class="reference external" href="http://2018.geopython.net/#s107">Understanding and Implementing Recurrent Neural Networks using Python</a>\n</li>\n<li>Have 8+ International Publications. [Latest work got published in ACM CHI 2018. The project was exhibited in Montreal, Canada.]</li>\n<li>Received 6 Honours and Awards (International and National level).</li>\n<li>Represented India at International Hackathons like Hack Junction\'16, Finland and Hack the North\'16, Canada. Got invited for more than a ‘dozen\' of prestigious International Hackathons (PennApps\'17, HackNY\'17, Hack Princeton\'17 and many more) and Conferences.</li>\n<li>A Microsoft Certified Professional, Microsoft Technology Associate, IBM Certified Web Developer, and Hewlett Packard Certified Developer.</li>\n<li>Former Software Developer Intern at IBM &amp; an ALL STACK DEVELOPER capable of designing and developing solutions for Mobile, Web, Embedded Systems, and Desktop. Areas of interest are Computational Neuroscience, Deep Learning, and Cloud Computing.</li>\n</ul>', 'anthony khong': '<p>I am always fascinated about programming languages. In particular, I have long advocated for the use of functional programming over object-oriented programming and a declarative style over an imperative one. Despite having used Python heavily since 2013, groking Scala, Haskell and Clojure really changed my style ...

# %%
data = []

for i in range(len(speakers)):
  try:
    subdata = {
        "title": titles[i],
        "speaker": speakers[i],
        "description": folded_str(descriptions[i]),
        "bio": literal_str(bio[speakers[i].lower()]),
        "speakerimg": speakerimg[speakers[i].lower()]
    }
    data.append(subdata)
  except:
    subdata = {
        "title": titles[i],
        "speaker": speakers[i],
        "description": folded_str(descriptions[i]),
    }
    data.append(subdata)
    print(speakers[i])
    
print(data)
# Out:
# Sam Witteveen + Martin Andrews
# [{'title': 'Python made my dream come true', 'speaker': 'AKSHAT SHARMA', 'description': 'Python helped me fulfill my teenage dream to visit silicon valley before turning 20. I won an intercollege hackathon for building a Vision app using python, which got selected me for silicon valley and eminent Harvard Conf. A senior from my college inspired me, now, I wish to inspire novices.', 'bio': "<p>Hie, I'm Akshat, a Govt. of India recognized Silicon Valley fellow and a Harvard University Conference Scholar. Currently, I'm working on the problem of distracted driving and recently built an Android app (visit: inSessionApp.com) to manage my calls and acknowledging callers while I sleep. I've previously worked at a Thailand based and a California based company. This summers, I'm working with an India based startup as a Software Engineer. Above all this, I love to empower people in my connection.</p>", 'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/48515/IMG_20180907_122310.jpeg'}, {'title': 'Kill the mutants, protect your code!', 'speaker': 'Alex Khaerov', 'description': "You definitely have unit tests. Your code coverage above 80 or 90? Are u still struggling with bugs and wanna increase the quality? What if I say that quarter of your units are non-viable mutants? Yes, it is true and sounds rude. Let's mutate your tests and look what it gets you.", 'bio': '<p><strong>Alex Khaerov</strong> is a development lead at <a class="reference external" href="https://chainstack.com">Chainstack</a>, with 9+ years in web services development across diverse domains. His main passion is building robust, high-load and distributed service platforms on top of a multi-cloud environment, utilizing all the power of Python and cloud native services. An organized of <a class="reference external" href="https://conf.python.ru">Moscow Python Conf</a> and avid activist of <a class="reference external" href="http://pugs.org.sg/">Singapore Python User Group</a>, cloud native enthusiast and member of Kubernetes SG community. In his spare time, he speaks publicly at tech conferences and secretly codes in Python. Huge fan of laptop stickers.</p>', 'speakerimg': 'https://secure.gravatar.com/avatar/320f3b558c773592bba16c976d1b28d1?s=500'}, {'title': 'From 0 to Awesome: How we got Python to supercharge our ML stack', 'speaker': 'Amir Arad', 'description': 'Python is now a crucial foundation in our org, with its dynamicity, user friendliness, and community-backed frameworks complementing the firepower we already had from Scala.', 'bio': '<p>Studied Math, building systems, loves traveling and puns.</p>', 'speakerimg': 'https://secure.gravatar.com/avatar/7ebded1e9171acbf1b8cbf3532e25172?s=500'}, {'title': 'AIoT: Intelligence on Low Power Microcontroller, with MicroPython', 'speaker': 'Andri Yadi', 'description': "AI + IoT = AIoT is the latest advancement of AI and IoT. Let's move beyond buzzword and seeing it in action. This session will show how to use MicroPython superpower to make Machine Learning (ML) inference runs right on the low power Microcontroller (MCU), not in the cloud, to build AIoT application", 'bio': '<p>CEO of DycodeX - the AIoT enabler in Indonesia. Microsoft Most Valuable Professional (MVP) of Microsoft Azure. 15 years as entrepreneur. A developer, hardware maker, and public speaker.</p>', 'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/47721/RIOT_DSC1564_copy.JPG'}, {'title': 'Understanding and Implementing Generative Adversarial Networks (GANs): One of the BIGGEST Breakthroughs in the Deep Learning Revolution', 'speaker': 'Anmol Krishan Sachdeva', 'description': "Generative Adversarial Networks are one of the latest advancements in Deep Learning. Interested in knowing how to generate content (images, music, and much more) instead of classifying one into categories? Let's dive into the details of GANs: One of the BIGGEST Breakthroughs in the DL Revolution.", 'bio': '<ul class="simp ...

# %%
with open('talks.yaml', 'w') as outfile:
  yaml.dump({"talks":data}, outfile, default_flow_style=False)

# %%
df = pandas.read_csv("PyConSchedule15.csv")
df
# Out:
#     Unnamed: 0  ... Unnamed: 25
# 0         7:30  ...         NaN
# 1         7:35  ...         NaN
# 2         7:40  ...         NaN
# 3         7:45  ...         NaN
# 4         7:50  ...         NaN
# 5         7:55  ...         NaN
# 6         8:00  ...         NaN
# 7         8:05  ...         NaN
# 8         8:10  ...         NaN
# 9         8:15  ...         NaN
# 10        8:20  ...         NaN
# 11        8:25  ...         NaN
# 12        8:30  ...         NaN
# 13        8:35  ...         NaN
# 14        8:40  ...         NaN
# 15        8:45  ...         NaN
# 16        8:50  ...         NaN
# 17        8:55  ...         NaN
# 18        9:00  ...         NaN
# 19        9:05  ...         NaN
# 20        9:10  ...         NaN
# 21        9:15  ...         NaN
# 22        9:20  ...         NaN
# 23        9:25  ...         NaN
# 24        9:30  ...         NaN
# 25        9:35  ...         NaN
# 26        9:40  ...         NaN
# 27        9:45  ...         NaN
# 28        9:50  ...         NaN
# 29        9:55  ...         NaN
# ..         ...  ...         ...
# 103      16:05  ...         NaN
# 104      16:10  ...         NaN
# 105      16:15  ...         NaN
# 106      16:20  ...         NaN
# 107      16:25  ...         NaN
# 108      16:30  ...         NaN
# 109      16:35  ...         NaN
# 110      16:40  ...         NaN
# 111      16:45  ...         NaN
# 112      16:50  ...         NaN
# 113      16:55  ...         NaN
# 114      17:00  ...         NaN
# 115      17:05  ...         NaN
# 116      17:10  ...         NaN
# 117      17:15  ...         NaN
# 118      17:20  ...         NaN
# 119      17:25  ...         NaN
# 120      17:30  ...         NaN
# 121      17:35  ...         NaN
# 122      17:40  ...         NaN
# 123      17:45  ...         NaN
# 124      17:50  ...         NaN
# 125      17:55  ...         NaN
# 126      18:00  ...         NaN
# 127      18:05  ...         NaN
# 128      18:10  ...         NaN
# 129      18:15  ...         NaN
# 130      18:20  ...         NaN
# 131      18:25  ...         NaN
# 132      18:30  ...         NaN
#
# [133 rows x 26 columns]

# %%
def fixln(x):
  return x.replace("\n"," ").replace("  "," ")

schedule = {}
for rowi,row in df.iterrows():
  if len(row[0]) == 4: row[0] = "0"+row[0]
  if not row[0] in schedule: schedule[row[0]] = []
  if str(row[1]) != "nan": schedule[row[0]].append(fixln(row[1]))
  if str(row[2]) != "nan": schedule[row[0]].append(fixln(row[2]))
  if str(row[3]) != "nan": schedule[row[0]].append(fixln(row[3]))
  if str(row[4]) != "nan": schedule[row[0]].append(fixln(row[4]))

schedule
# Out:
# {'07:30': ['Women Who Code Breakfast'],
#  '07:35': [],
#  '07:40': [],
#  '07:45': [],
#  '07:50': [],
#  '07:55': [],
#  '08:00': ['Registration / Welcome Coffee'],
#  '08:05': [],
#  '08:10': [],
#  '08:15': [],
#  '08:20': [],
#  '08:25': [],
#  '08:30': [],
#  '08:35': [],
#  '08:40': [],
#  '08:45': [],
#  '08:50': [],
#  '08:55': ['Welcome Speech'],
#  '09:00': [],
#  '09:05': ['Keynote Speech David Cournapeau How to meaningfully contribute to Python without being very good at programming'],
#  '09:10': [],
#  '09:15': [],
#  '09:20': [],
#  '09:25': [],
#  '09:30': [],
#  '09:35': [],
#  '09:40': [],
#  '09:45': [],
#  '09:50': ['Coffee and Networking Break'],
#  '09:55': [],
#  '10:00': [],
#  '10:05': [],
#  '10:10': [],
#  '10:15': [],
#  '10:20': ['Interactive Python Dashboards with Plotly and Dash ',
#   'Machine Learning Democratization with Python ',
#   'Unique ways to Hack into a Python Web Service ',
#   'Python For Beginners'],
#  '10:25': [],
#  '10:30': [],
#  '10:35': [],
#  '10:40': [],
#  '10:45': [],
#  '10:50': [],
#  '10:55': [],
#  '11:00': ['Break'],
#  '11:05': [],
#  '11:10': ['Production-ize deep learning with PyTorch, RedisAI and Hangar',
#   'Raiden Network for instant crypto payment & lower fees',
#   'Demystifying Conversational AI with Python '],
#  '11:15': [],
#  '11:20': [],
#  '11:25': [],
#  '11:30': [],
#  '11:35': [],
#  '11:40': [],
#  '11:45': [],
#  '11:50': ['Break'],
#  '11:55': [],
#  '12:00': ['Designing and Building Serverless Machine Learning-powered Applications with Python *',
#   'XXX',
#   'Automate the Boring Stuff with Slackbot'],
#  '12:05': [],
#  '12:10': [],
#  '12:15': [],
#  '12:20': [],
#  '12:25': [],
#  '12:30': [],
#  '12:35': [],
#  '12:40': ['Lunch Break'],
#  '12:45': [],
#  '12:50': [],
#  '12:55': [],
#  '13:00': [],
#  '13:05': [],
#  '13:10': [],
#  '13:15': [],
#  '13:20': [],
#  '13:25': [],
#  '13:30': [],
#  '13:35': [],
#  '13:40': ["How pyThaiNLP's thai2fit Outperforms Google's BERT: State-of-the-Art Thai Text Classification and Beyond",
#   'E-commerce for Django (in Thai)',
#   'Understanding and Implementing Generative Adversarial Networks: One of the BIGGEST Breakthroughs in the Deep Learning Revolution ',
#   'Deep Learning Introductory Workshop with TensorFlow 2.0'],
#  '13:45': [],
#  '13:50': [],
#  '13:55': [],
#  '14:00': [],
#  '14:05': [],
#  '14:10': [],
#  '14:15': [],
#  '14:20': ['Break'],
#  '14:25': [],
#  '14:30': ['Addressing class imbalance in Machine Learning',
#   'Marlin: A Smali to Python Transpiler for Android Hacking',
#   'JWT authentication with Django'],
#  '14:35': [],
#  '14:40': [],
#  '14:45': [],
#  '14:50': [],
#  '14:55': [],
#  '15:00': [],
#  '15:05': [],
#  '15:10': ['Break'],
#  '15:15': [],
#  '15:20': ['Program Thinking: How do you design programs for diversity? *',
#   'Advanced Google Colaboratory ',
#   'Facial Keypoints Detection with PyTorch'],
#  '15:25': [],
#  '15:30': [],
#  '15:35': [],
#  '15:40': [],
#  '15:45': [],
#  '15:50': [],
#  '15:55': [],
#  '16:00': ['Break'],
#  '16:05': [],
#  '16:10': ['Python in Production Engineering @ Facebook ',
#   'Kill the mutants, protect your code! ',
#   'When life gives you Orange, make data speak volumes! '],
#  '16:15': [],
#  '16:20': [],
#  '16:25': [],
#  '16:30': [],
#  '16:35': [],
#  '16:40': [],
#  '16:45': [],
#  '16:50': ['Break'],
#  '16:55': [],
#  '17:00': ['Lightning Talks'],
#  '17:05': [],
#  '17:10': [],
#  '17:15': [],
#  '17:20': [],
#  '17:25': [],
#  '17:30': [],
#  '17:35': [],
#  '17:40': [],
#  '17:45': ['Keynote Speech Adam Paszke PyTorch as a modern scientific computing environment'],
#  '17:50': [],
#  '17:55': [],
#  '18:00': [],
#  '18:05': [],
#  '18:10': [],
#  '18:15': [],
#  '18:20': [],
#  '18:25': [],
#  '18:30': []}

# %%
""""
Goal is to talk a yaml file of talks data and produce
- responsive schedule
- talks page
- speakers page
- embeded videos
- all linked together
Schedule grid assumes talks don't end in the middle of other talks.
Layout alg is
[11-12
  [11-11:30
"""


import yaml
try:
    from yaml import CLoader as Loader, CDumper as Dumper
except ImportError:
    from yaml import Loader, Dumper

with open('talks2019.yaml') as f:
    data = yaml.load(f, Loader=Loader)

talks = sorted([t for t in data['talks'] if 'day' in t], key=lambda t: (t['day'],t['time'],t['dur'],t['track']))


sched = []

cur = None
for talk in talks:
    if talk['time'] != cur:
        cur = talk['time']
        dur = talk['dur']
        slot = dict(time=cur, dur=dur, talks=[])
        sched.append(slot)
    # now try to fit in the track
    slot['talks'].append(talk)

print(talks)
sched

schedule = {}
currrow = 1
for s in sched:
  time = s['time']
  if not time in schedule: schedule[time] = []
  for talk in s['talks']:
    talk['row'] = currrow
    talk['col'] = 1 if talk['track'] != 4 else 2
    if 'track' in talk:
      talk['subcol'] = 5 if type(talk['track']) == list else talk['track']
      talk['colspan'] = 2 if talk['track'] == [1,2,3,4] else 1
    else:
      talk['subcol'] = 1
      talk['colspan'] = 2
    talk['time'] = time
    schedule[time].append(talk)
  currrow += 1
    
html = ''

currday = ""
rowoffset = 0

for t in schedule:
  s = schedule[t]
  if len(s) == 0: continue
  talk = s[0]
  if talk['day'] != currday:
    if currday != "": html += "</div>"
    html += '<h2>' + talk['day'] + '</h2> <div class="grid-container">'
    currday = talk['day']
    rowoffset = talk['row']-1
  subhtml = '<div class="timeflex" style="grid-row-start: {}; grid-row-end: {}; grid-column-start: {}; grid-column-end: {};"> <div class="timetext"><b>{}</b></div> <div class="schedule-item-container" style="flex-grow:1;">'.format(talk['row']-rowoffset,talk['row']-rowoffset,talk['col'],talk['col']+talk['colspan'],t)#,talk['row'],talk['row'],talk['col'],talk['col']+talk['colspan'])
  for talk in s:
    if talk['col'] == 1:
      subhtml += '''		<div class="schedule-item schedule-item-{}" style="order: {};">
			<div><b>{}</b></div>
			<div>{}</div>
		</div>'''.format(talk['subcol'],talk['subcol']-1,talk['title'],talk['speaker'])
  subhtml += '</div> </div>'
  for talk in s:
    if talk['col'] == 2:
      subhtml += '''	<div class="workshop-item" style="grid-row-start:{}; grid-row-end:{}; grid-column-start: {}; grid-column-end: {};">
		<div class="workshop-text">
			<b>{}</b><br>{}
		</div>
	</div>'''.format(talk['row']-rowoffset,talk['row']-rowoffset+3,talk['col'],talk['col'],talk['title'],talk['speaker'])
  html += subhtml

print(html)

schedule
# Out:
# [{'bio': 'Catered by ...', 'description': 'Served on Level 6', 'speaker': '...', 'speakerimg': None, 'title': 'Morning Tea & Coffee', 'day': 'sat', 'track': [1, 2, 3, 4], 'time': '09:50', 'dur': '00:30'}, {'bio': '<p>Hello, I am Doni Rubiagatra. I am Software Engineer at <a class="reference external" href="https://kumparan.com">kumparan</a>, co-founder of <a class="reference external" href="https://github.com/surabaya-py,andAdvisorat%5BDataScienceIndonesia%5D(https://datascience.or.id">surabaya.py</a> East Java. I love teaching Python to others and spoke at several PyCon in Asia. I scream for an Ice Cream :D</p>', 'description': 'In the interactive visualization world mainly we hear about Tableau and Shiny for R. How about Python? Python’s visualization landscape is quite complex with many available libraries. In this talk, we will look for an easy and fun way to build an interactive dashboard using Plotly and Dash', 'speaker': 'Doni Rubiagatra', 'speakerimg': 'https://secure.gravatar.com/avatar/eed0ef6cc8a0f435d5d8c9a5648f1551?s=500', 'title': 'Interactive Python Dashboards with Plotly and Dash', 'day': 'sat', 'track': 1, 'time': '10:20', 'dur': '00:40'}, {'bio': '<p>Jorge Torres Is currently Co-founder &amp; CTO of MindsDB and a visiting scholar at UC Berkeley researching machine learning automation and explainability. He has worked for a number of data-intensive start-ups, most recently working with Aneesh Chopra (the first CTO in the US government) building data systems that analyze billions of patients records and lead to highest savings for millions of patients, he started his work on scaling solutions using machine learning in early 2008 while working as first full time engineer at Couchsurfing where he helped grow the company from a few thousand users to a few million. Jorge had degrees in electrical engineering &amp; computer science, including a masters degree in computer systems (with a focus on applied Machine Learning) from the Australian National University.</p>', 'description': 'It is crucial to rethink how we build tools so that we can provide Machine Learning capabilities to experts in various disciplines that are not necessarily savvy in machine learning, this talk we talk about our project that allows anyone to create and use sophisticated ML in one line of python code.', 'speaker': 'Jorge Torres', 'speakerimg': 'https://secure.gravatar.com/avatar/03886c577a1c4d30efa531b8f85aa80f?s=500', 'title': 'Machine Learning Democratization with Python', 'day': 'sat', 'track': 2, 'time': '10:20', 'dur': '00:40'}, {'bio': '<p>I work at an Application Security company (we45) and have a unique perspective of developing secure and deliberately insecure apps in Python and NodeJS. I have contributed to the development of several Web-Applications using Django, Djano-Rest-Framework, NodeJs and more, that have been used for Capture the Flag Contests inside and outside the organization. And also I am contributed multiple OpenSource Projects. In addition, I have extensive experience with integrating scanners, SAST and DAST toolsets into our Application Vulnerability Correlation and Aggregation product. I have over 7 years of development experience and continue to work as a full-stack developer. And also I have presented talk in DjangoCon 2018, ISACA Meetup, also gave a workshop about container orchestration and Serverless in Lascon, Recently gave a talk in DevSecCon Singapore 2019.</p>', 'description': "Microservices are taking over the world. Rest-framework is accelerating this because of its ease and flexibility.\nDevelopers often use and develop REST-based applications because it's exciting to work with. But, they forget about security which leads to compromised and exploited applications.", 'speaker': 'Tilak T', 'speakerimg': 'https://secure.gravatar.com/avatar/3852521603c21de17cdab3adf97ac91a?s=500', 'title': 'Unique ways to Hack into a Python Web Service', 'day': 'sat', 'track': 3, 'time': '10:20', 'dur': '00:40'}, {'bio':  ...
# <h2>sat</h2> <div class="grid-container"><div class="timeflex" style="grid-row-start: 1; grid-row-end: 1; grid-column-start: 1; grid-column-end: 3;"> <div class="timetext"><b>09:50</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-5" style="order: 4;">
# 			<div><b>Morning Tea & Coffee</b></div>
# 			<div>...</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Python made my dream come true</b></div>
# 			<div>AKSHAT SHARMA</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 2; grid-row-end: 2; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>10:20</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-1" style="order: 0;">
# 			<div><b>Interactive Python Dashboards with Plotly and Dash</b></div>
# 			<div>Doni Rubiagatra</div>
# 		</div>		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Machine Learning Democratization with Python</b></div>
# 			<div>Jorge Torres</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Unique ways to Hack into a Python Web Service</b></div>
# 			<div>Tilak T</div>
# 		</div></div> </div>	<div class="workshop-item" style="grid-row-start:2; grid-row-end:5; grid-column-start: 2; grid-column-end: 2;">
# 		<div class="workshop-text">
# 			<b>Python for beginners</b><br>Sudarat Chattanon
# 		</div>
# 	</div><div class="timeflex" style="grid-row-start: 3; grid-row-end: 3; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>11:10</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-1" style="order: 0;">
# 			<div><b>Production-ize deep learning with PyTorch, RedisAI and Hangar</b></div>
# 			<div>Sherin Thomas</div>
# 		</div>		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Raiden Network for instant crypto payment & lower fees</b></div>
# 			<div>Pisuth Daengthongdee</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 4; grid-row-end: 4; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>12:00</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>The Buzz about Bees</b></div>
# 			<div>Robert Owen</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Automate the Boring Stuff with Slackbot</b></div>
# 			<div>Takanori Suzuki</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 5; grid-row-end: 5; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>12:30</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>JWT authentication with Django</b></div>
# 			<div>Viral Parmar</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 6; grid-row-end: 6; grid-column-start: 1; grid-column-end: 3;"> <div class="timetext"><b>12:40</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-5" style="order: 4;">
# 			<div><b>Lunch</b></div>
# 			<div>Ginger Farm</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 7; grid-row-end: 7; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>13:40</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>E-commerce for Django</b></div>
# 			<div>Jonghwa Seo</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Understanding and Implementing Generative Adversarial Networks (GANs): One of the BIGGEST Breakthroughs in the Deep Learning Revolution</b></div>
# 			<div>Anmol Krishan Sachdeva</div>
# 		</div></div> </div>	<div class="workshop-item" style="grid-row-start:7; grid-row-end:10; grid-column-start: 2; grid-column-end: 2;">
# 		<div class="workshop-text">
# 			<b>Deep Learning Introductory Workshop with TensorFlow 2.0</b><br>Sam Witteveen + Martin Andrews
# 		</div>
# 	</div><div class="timeflex" style="grid-row-start: 8; grid-row-end: 8; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>15:20</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Facial Keypoints Detection with PyTorch</b></div>
# 			<div>Nithiroj Tripatarasit</div>
# 		</div>		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Advanced Google Colaboratory</b></div>
# 			<div>Korakot Chaovavanich</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 9; grid-row-end: 9; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>16:10</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>When life gives you Orange, make data speak volumes!</b></div>
# 			<div>Drishti Jain</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 10; grid-row-end: 10; grid-column-start: 1; grid-column-end: 3;"> <div class="timetext"><b>17:00</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-5" style="order: 4;">
# 			<div><b>Lightning Talks</b></div>
# 			<div>Signup</div>
# 		</div></div> </div></div><h2>sun</h2> <div class="grid-container"><div class="timeflex" style="grid-row-start: 1; grid-row-end: 1; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>09:00</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-1" style="order: 0;">
# 			<div><b>Fuzzy Multi-Criteria Portfolio Optimisation with Python (and maybe a little bit of Mathematica)</b></div>
# 			<div>Poomjai Nacaskul, PhD, DIC, CFA</div>
# 		</div>		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Developing Natural Language Processing Applications Using Python</b></div>
# 			<div>TUSHAR BANSAL</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Ready to say goodbye to Python 2.7 ! ?</b></div>
# 			<div>Noah</div>
# 		</div></div> </div>	<div class="workshop-item" style="grid-row-start:1; grid-row-end:4; grid-column-start: 2; grid-column-end: 2;">
# 		<div class="workshop-text">
# 			<b>Teaching Coding To Kids</b><br>Mishari Muqbil
# 		</div>
# 	</div><div class="timeflex" style="grid-row-start: 3; grid-row-end: 3; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>10:40</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Security Issues on your Python Code</b></div>
# 			<div>Harley Davidson Karel</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 4; grid-row-end: 4; grid-column-start: 1; grid-column-end: 3;"> <div class="timetext"><b>12:15</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-5" style="order: 4;">
# 			<div><b>Lunch</b></div>
# 			<div>Ginger Farm</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 5; grid-row-end: 5; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>13:15</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-1" style="order: 0;">
# 			<div><b>Understanding of distributed processing in Python</b></div>
# 			<div>Chie Hayashida</div>
# 		</div>		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Python for Data Science Projects at Coraline</b></div>
# 			<div>Jiranun Jiratrakanvong</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Functional Programming in Python: Lessons from Haskell and Clojure</b></div>
# 			<div>Anthony Khong</div>
# 		</div></div> </div>	<div class="workshop-item" style="grid-row-start:5; grid-row-end:8; grid-column-start: 2; grid-column-end: 2;">
# 		<div class="workshop-text">
# 			<b>Visualize the Black Box - An introduction to Interpretable Machine Learning</b><br>Rahul Bhatia
# 		</div>
# 	</div><div class="timeflex" style="grid-row-start: 6; grid-row-end: 6; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>14:05</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-1" style="order: 0;">
# 			<div><b>From 0 to Awesome: How we got Python to supercharge our ML stack</b></div>
# 			<div>Amir Arad</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>Hypothesis: Property-Based Testing for Python</b></div>
# 			<div>Rae Knowler</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 7; grid-row-end: 7; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>14:55</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-1" style="order: 0;">
# 			<div><b>Adding a GraphQL API to Django (with Vue.js frontend)</b></div>
# 			<div>Manuel Riel</div>
# 		</div>		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Unlocking the power of natural language by machine translation: how python could serve my purpose?</b></div>
# 			<div>Mohamed Ali SOLA (Dali SOLA)</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>A resilient, scalable tracing and analysis system for micro-services - HayStack</b></div>
# 			<div>Sarthak Deshwal</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 9; grid-row-end: 9; grid-column-start: 1; grid-column-end: 2;"> <div class="timetext"><b>15:45</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-1" style="order: 0;">
# 			<div><b>First steps in Deep Learning with TensorFlow 2.0 : CNNs</b></div>
# 			<div>Martin Andrews</div>
# 		</div>		<div class="schedule-item schedule-item-2" style="order: 1;">
# 			<div><b>Any Code Formatter You Like - As Long As It's Black</b></div>
# 			<div>Zsolt Dollenstein</div>
# 		</div>		<div class="schedule-item schedule-item-3" style="order: 2;">
# 			<div><b>How to build an open source catbot with Python, a 3D printer and a microcontroller</b></div>
# 			<div>Chanapai Chuadchum</div>
# 		</div></div> </div><div class="timeflex" style="grid-row-start: 10; grid-row-end: 10; grid-column-start: 1; grid-column-end: 3;"> <div class="timetext"><b>16:35</b></div> <div class="schedule-item-container" style="flex-grow:1;">		<div class="schedule-item schedule-item-5" style="order: 4;">
# 			<div><b>Lightning Talks</b></div>
# 			<div>Signup</div>
# 		</div></div> </div>
# {'09:00': [{'bio': "<p>I am a Data Scientist (First Senior Vice President) at Siam Commercial Bank PCL. Beside Python, I'm also into Mathematica, and did my doctorate entirely in C++. Beside Data Science, I'm involved in Quantitative Analytics in general, Financial Engineering and Risk Management in particular (although much less so these days). Beside Machine Learning, my research interest span to Graph-Theoretic/Network Model, Copula Functional, Cybernetics, and (obviously) Fuzzy Multi-Criteria Decision Model.</p>",
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': "Today's sophisticated investors/fund managers require more flexibility/sophistication than traditional risk/return bi-criteria analysis. The talk introduces Python-based, highly-customisable Fuzzy Multi-Criteria Portfolio Optimisation framework and asset allocation solution.",
#    'dur': '00:40',
#    'row': 11,
#    'speaker': 'Poomjai Nacaskul, PhD, DIC, CFA',
#    'speakerimg': 'https://secure.gravatar.com/avatar/02ef5c925c1e92968925675e253a72cc?s=500',
#    'subcol': 1,
#    'time': '09:00',
#    'title': 'Fuzzy Multi-Criteria Portfolio Optimisation with Python (and maybe a little bit of Mathematica)',
#    'track': 1},
#   {'bio': '<p>I am a pre final student at The LNM Institute of Information Technology pursuing B-Tech in Computer Science Engineering. I have a Deep interest in open source technologies, and was selected as Mozilla Open Leader this year. I like to code in Python and developing Natural Language Processing applications in python. I have studied Information Retrieval as an academic course and my my interest in this field grew from there. In this talk I will elaborate on my project where I used TWEEPY library of python to extract and evaluate tweets. I believe Information Retrieval is a interesting topic and will attract audience from all the field and all experience levels.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'I will talk about NLP at first and introduce the concept of NLP, algorithms for Lexicon Normalization, Entity Parsing etc. Then I will talk about Python Libraries like NLTK, TextBlob, GenSim, spaCy & the functionalities they provide. Lastly, I will elaborate on how I used all of these in my project.',
#    'dur': '00:40',
#    'row': 11,
#    'speaker': 'TUSHAR BANSAL',
#    'speakerimg': 'https://secure.gravatar.com/avatar/702e5bb554b9e0dbcf2412f9d8929aa2?s=500',
#    'subcol': 2,
#    'time': '09:00',
#    'title': 'Developing Natural Language Processing Applications Using Python',
#    'track': 2},
#   {'bio': '<p>Noah,\nPyCon Nomad\nVolunteer of FOSSASIA which is a NPO for promoting FOSS and open technologies in Asia,\nvolunteer of PyConTW/JP/KR/ID/MY/TH/HK.....and each PyConAPAC since 2015.\nvolunteer and speaker of EuroPython 2018.\nManaging member of PSF,\nmy wish is that connect everyone who enjoy Python, and try to promote programming education to young generation or everyone who interested in by teaching basic programming skill using Python and R, like be a mentor of Hour or Code, or Google Summer of Code with FOSSASIA</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': "according to PEP 373, we knew Python 2.7 EOL is moved to 2020. in PEP 404, we knew Python 2.8 will never come, which means all versions of Python 2 will be end of official bugfix and support at EOL.\n2019, the last year of Python2. let's review how glory memories is in history of Python.",
#    'dur': '00:40',
#    'row': 11,
#    'speaker': 'Noah',
#    'speakerimg': 'https://secure.gravatar.com/avatar/f84b4128e61163fad7751e4dd8ebac50?s=500',
#    'subcol': 3,
#    'time': '09:00',
#    'title': 'Ready to say goodbye to Python 2.7 ! ?',
#    'track': 3},
#   {'bio': '<p>CEO of Zymple</p>',
#    'col': 2,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'This is a workshop for adults such as parents, teachers, community organizers and others interested in organizing classes where kids learn how to program Python in a peer to peer, collaborative learning environment.',
#    'dur': '02:20',
#    'row': 11,
#    'speaker': 'Mishari Muqbil',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/27090/IMG-0002.JPG',
#    'subcol': 4,
#    'time': '09:00',
#    'title': 'Teaching Coding To Kids',
#    'track': 4}],
#  '09:50': [{'bio': 'Catered by ...',
#    'col': 1,
#    'colspan': 2,
#    'day': 'sat',
#    'description': 'Served on Level 6',
#    'dur': '00:30',
#    'row': 1,
#    'speaker': '...',
#    'speakerimg': None,
#    'subcol': 5,
#    'time': '09:50',
#    'title': 'Morning Tea & Coffee',
#    'track': [1, 2, 3, 4]},
#   {'bio': "<p>Hie, I'm Akshat, a Govt. of India recognized Silicon Valley fellow and a Harvard University Conference Scholar. Currently, I'm working on the problem of distracted driving and recently built an Android app (visit: inSessionApp.com) to manage my calls and acknowledging callers while I sleep. I've previously worked at a Thailand based and a California based company. This summers, I'm working with an India based startup as a Software Engineer. Above all this, I love to empower people in my connection.</p>",
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'Python helped me fulfill my teenage dream to visit silicon valley before turning 20. I won an intercollege hackathon for building a Vision app using python, which got selected me for silicon valley and eminent Harvard Conf. A senior from my college inspired me, now, I wish to inspire novices.',
#    'dur': '00:40',
#    'row': 12,
#    'speaker': 'AKSHAT SHARMA',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/48515/IMG_20180907_122310.jpeg',
#    'subcol': 3,
#    'time': '09:50',
#    'title': 'Python made my dream come true',
#    'track': 3}],
#  '10:20': [{'bio': '<p>Hello, I am Doni Rubiagatra. I am Software Engineer at <a class="reference external" href="https://kumparan.com">kumparan</a>, co-founder of <a class="reference external" href="https://github.com/surabaya-py,andAdvisorat%5BDataScienceIndonesia%5D(https://datascience.or.id">surabaya.py</a> East Java. I love teaching Python to others and spoke at several PyCon in Asia. I scream for an Ice Cream :D</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'In the interactive visualization world mainly we hear about Tableau and Shiny for R. How about Python? Python’s visualization landscape is quite complex with many available libraries. In this talk, we will look for an easy and fun way to build an interactive dashboard using Plotly and Dash',
#    'dur': '00:40',
#    'row': 2,
#    'speaker': 'Doni Rubiagatra',
#    'speakerimg': 'https://secure.gravatar.com/avatar/eed0ef6cc8a0f435d5d8c9a5648f1551?s=500',
#    'subcol': 1,
#    'time': '10:20',
#    'title': 'Interactive Python Dashboards with Plotly and Dash',
#    'track': 1},
#   {'bio': '<p>Jorge Torres Is currently Co-founder &amp; CTO of MindsDB and a visiting scholar at UC Berkeley researching machine learning automation and explainability. He has worked for a number of data-intensive start-ups, most recently working with Aneesh Chopra (the first CTO in the US government) building data systems that analyze billions of patients records and lead to highest savings for millions of patients, he started his work on scaling solutions using machine learning in early 2008 while working as first full time engineer at Couchsurfing where he helped grow the company from a few thousand users to a few million. Jorge had degrees in electrical engineering &amp; computer science, including a masters degree in computer systems (with a focus on applied Machine Learning) from the Australian National University.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'It is crucial to rethink how we build tools so that we can provide Machine Learning capabilities to experts in various disciplines that are not necessarily savvy in machine learning, this talk we talk about our project that allows anyone to create and use sophisticated ML in one line of python code.',
#    'dur': '00:40',
#    'row': 2,
#    'speaker': 'Jorge Torres',
#    'speakerimg': 'https://secure.gravatar.com/avatar/03886c577a1c4d30efa531b8f85aa80f?s=500',
#    'subcol': 2,
#    'time': '10:20',
#    'title': 'Machine Learning Democratization with Python',
#    'track': 2},
#   {'bio': '<p>I work at an Application Security company (we45) and have a unique perspective of developing secure and deliberately insecure apps in Python and NodeJS. I have contributed to the development of several Web-Applications using Django, Djano-Rest-Framework, NodeJs and more, that have been used for Capture the Flag Contests inside and outside the organization. And also I am contributed multiple OpenSource Projects. In addition, I have extensive experience with integrating scanners, SAST and DAST toolsets into our Application Vulnerability Correlation and Aggregation product. I have over 7 years of development experience and continue to work as a full-stack developer. And also I have presented talk in DjangoCon 2018, ISACA Meetup, also gave a workshop about container orchestration and Serverless in Lascon, Recently gave a talk in DevSecCon Singapore 2019.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': "Microservices are taking over the world. Rest-framework is accelerating this because of its ease and flexibility.\nDevelopers often use and develop REST-based applications because it's exciting to work with. But, they forget about security which leads to compromised and exploited applications.",
#    'dur': '00:40',
#    'row': 2,
#    'speaker': 'Tilak T',
#    'speakerimg': 'https://secure.gravatar.com/avatar/3852521603c21de17cdab3adf97ac91a?s=500',
#    'subcol': 3,
#    'time': '10:20',
#    'title': 'Unique ways to Hack into a Python Web Service',
#    'track': 3},
#   {'bio': "<p>Hi there! I am a software engineer who uses vim at Pronto Tools and also a GirlsWhoDev organizer for around 4 years. I have organized many tech events for girls who want to learn coding even if they are not in the tech industry such as girls learning Python. I am also a co-organiser with Django girls for building a website with Django in Bangkok. Apart from my tech life, I'm a dog person. I enjoy singing, dancing and watching a movie and a series.</p>",
#    'col': 2,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Have you ever use a cutie and cool CLI tool? Have you felt that it is very cool and makes you feel so excited to use this tool? This workshop will help you learn how to build your own CLI using basic Python skill and makes everyone love it.',
#    'dur': '02:20',
#    'row': 2,
#    'speaker': 'Sudarat Chattanon',
#    'speakerimg': 'https://secure.gravatar.com/avatar/7300910aa33d37a8a78a64270f6283b0?s=500',
#    'subcol': 4,
#    'time': '10:20',
#    'title': 'Python for beginners',
#    'track': 4}],
#  '10:40': [{'bio': "<p>Application Security Consultant, Skilled in Security Requirement Engineering, Threat Modeling, Static Application Security Testing, Dynamic Application Security Testing,  Secure SDLC, DevSecOps. Hold Certified Ethical Hacker certification, Speaker for several conferences in Jakarta, Kuala Lumpur, Singapore with topic related to application security.\nBachelor's Degree focused in Informatics Engineering from Telkom University.</p>",
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'This topic will cover how to find security issue on python code using open source Static Analysis Security Testing. So that developer can found & fixed the security issue since on development stage, without waiting for penetration testing stage',
#    'dur': '00:40',
#    'row': 13,
#    'speaker': 'Harley Davidson Karel',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/28808/David.jpg',
#    'subcol': 2,
#    'time': '10:40',
#    'title': 'Security Issues on your Python Code',
#    'track': 2}],
#  '11:10': [{'bio': '<p>I am working as a part of the development team of [Tensor]werk, an infrastructure development company focusing on deep learning deployment problems. I and my team focus on building open source tools for setting up a seamless deep learning workflow. I have been programming since 2012 and started using python since 2014 and moved to deep learning in 2015. I am an open source enthusiast and I spend most of my research time on improving interpretability of AI models using <a class="reference external" href="https://turingnetwork.ai">TuringNetwork</a>. I have authored a deep learning book (<a class="reference external" href="https://github.com/hhsecond/HandsOnDeepLearningWithPytorch">yet to publish</a>). I go by hhsecond on internet</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Managing DL workflow is always a nightmare. Problems include handling the scale, efficient resource utilization, version controlling the data. With the highly optimized RedisAI, super flexible PyTorch and heavily organized Hangar, all the sleepless nights are stories of the past.',
#    'dur': '00:40',
#    'row': 3,
#    'speaker': 'Sherin Thomas',
#    'speakerimg': 'https://secure.gravatar.com/avatar/c32e9a85da547a9e816d5ff6696957e8?s=500',
#    'subcol': 1,
#    'time': '11:10',
#    'title': 'Production-ize deep learning with PyTorch, RedisAI and Hangar',
#    'track': 1},
#   {'bio': '<p>Pisuth turns himself into a blockchain developer with extensive skills on IoT and Chatbot since 2017. Prior that time, he was working in media industry for 8 years in Thailand experienced using Python on system monitoring and systems integration.  He also won 7 blockchain competition/hackathon in the past 2 years include ETHSingapore, Binance and NEO and has strong passion on blockchain technology and distributed economy.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Raiden network is an open source project aims to bring several advantages like better privacy, speed, and lower fees to the Ethereum blockchain. This talk would focus on how to install, use cases, integration and its underlying technology.',
#    'dur': '00:40',
#    'row': 3,
#    'speaker': 'Pisuth Daengthongdee',
#    'speakerimg': 'https://secure.gravatar.com/avatar/02db6091a997dc75b39fddfe6a740494?s=500',
#    'subcol': 2,
#    'time': '11:10',
#    'title': 'Raiden Network for instant crypto payment & lower fees',
#    'track': 2}],
#  '12:00': [{'bio': '<p>Robert Owen worked for Oracle as Program Director for Asia-Pacific. Before that he worked for Ericsson Telecommunications. Robert was a member of the Australian delegation to the International Telecommunications Union, ITU, in Geneva, Switzerland where he worked on global telecommunications policy. A few years ago he spat his dummy at the amount of work Oracle expected him to do, resigned and enrolled for a PhD at the University of Melbourne, Australia. He expects to complete his PhD computer modelling infectious animal diseases later this year.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Models are used to simulate the spread of diseases in populations. Scientists often cannot base their decisions on past events but must take action quickly to halt their spread. Computer modelling in Python using random processes can help formulate actions to stem the spread of contagious diseases.',
#    'dur': '00:40',
#    'row': 4,
#    'speaker': 'Robert Owen',
#    'speakerimg': 'https://secure.gravatar.com/avatar/3bd96a0518aafe7632c76cccabc3501d?s=500',
#    'subcol': 2,
#    'time': '12:00',
#    'title': 'The Buzz about Bees',
#    'track': 2},
#   {'bio': '<p>Takanori is a Vice Chairperson of PyCon JP Committee(www.pycon.jp).\nHe is also a director of BeProud Inc.(www.beproud.jp), and his title is "Python Climber".\nTakanori held PyCon JP 2014 to 2016 as the chairperson.\nCurrently he teaches Python to beginners as a lecturer at Python Boot Camp(pycamp.pycon.jp) all over Japan.\nIn addition, he published several Python books.\nTananori plays trumpet, climbs boulder, loves Lego, ferrets and beer</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Today, there are many tasks to repeat in the community.\nWe often use chat such for daily communication.\nI created a chatbot to automate various boring tasks.\nIn this talk, I will tell you how to create a simple bot in Python and I will explain how to make a bot command to perform some operations.',
#    'dur': '00:40',
#    'row': 4,
#    'speaker': 'Takanori Suzuki',
#    'speakerimg': 'https://secure.gravatar.com/avatar/5d9cabab536050d85bfa0df9daf856d1?s=500',
#    'subcol': 3,
#    'time': '12:00',
#    'title': 'Automate the Boring Stuff with Slackbot',
#    'track': 3}],
#  '12:15': [{'bio': 'Catered by Ginger Farm',
#    'col': 1,
#    'colspan': 2,
#    'day': 'sun',
#    'description': 'Lunchboxes will be served on Level 6 and Level 7',
#    'dur': '01:00',
#    'row': 14,
#    'speaker': 'Ginger Farm',
#    'speakerimg': None,
#    'subcol': 5,
#    'time': '12:15',
#    'title': 'Lunch',
#    'track': [1, 2, 3, 4]}],
#  '12:30': [{'bio': '<p>Viral Parmar is a Serial entrepreneur who runs ComExpo Cyber security company as well as Infinite Defense Foundation a non-profit organization in India. He is a Developer Advocate, Productivity Hacker, Open Source Strategist, Technical Evangelist, Community Liaison, International TechSpeaker, he is a Cyber Security researcher by profession and open source enthusiast working in a field of information security from last three years with the expertise in Cyber Crime Investigation, Public Key Infrastructure, Social Engineering, Web App Penetration Testing, Digital Forensics and Mobile Security. He found sever vulnerability in 150+ well known websites like Intel, your story and solved more than 100 cases of cyber-crime &amp; online frauds. He is famous for his research Cyber Disorder and Who is spying on you. Trained 150,000+ people till now and aware them about privacy and security. Given Seminars and workshops in 150+ Organizations. He is Working with Mozilla foundation from last 2 years as Reps, Mentor in Mozilla Open Leadership Project, Coach(Privacy and Security) in MozSprint 2018, also working with L10N project on Pontoon, Rust and WebVR projects.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Talk is about the JWT Authentication with Django which plays an important role in modern day application development where it is a lot more than just the login screen, People will get know about different ways of authentication and authorization, concepts that make up modern identity.',
#    'dur': '00:40',
#    'row': 5,
#    'speaker': 'Viral Parmar',
#    'speakerimg': 'https://secure.gravatar.com/avatar/f39b54f90f14174754a7a1671cc8b008?s=500',
#    'subcol': 3,
#    'time': '12:30',
#    'title': 'JWT authentication with Django',
#    'track': 3}],
#  '12:40': [{'bio': 'Catered by Ginger Farm',
#    'col': 1,
#    'colspan': 2,
#    'day': 'sat',
#    'description': 'Lunchboxes will be served on Level 6 and Level 7',
#    'dur': '01:00',
#    'row': 6,
#    'speaker': 'Ginger Farm',
#    'speakerimg': None,
#    'subcol': 5,
#    'time': '12:40',
#    'title': 'Lunch',
#    'track': [1, 2, 3, 4]}],
#  '13:15': [{'bio': '<p>Chie Hayashida is a Software Engineer from Japan. She is working at Cookpad.Inc which is the worldwide recipe sharing service. She loves programming and computer science. She is highly skilled with DWH architecture and ML pipelines. She is a contributor to Apache Spark, Tensorflow, Apache Airflow and so on.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'There are several ways and libraries for distributed processing using Python. We need to understand the concepts and features of these libraries for efficient usage of computing resources. In this session, I will discuss how to be good to choose and use these distributed processing libraries.',
#    'dur': '00:40',
#    'row': 15,
#    'speaker': 'Chie Hayashida',
#    'speakerimg': 'https://secure.gravatar.com/avatar/7f7abff13e7c5ad15bfa3a823313ef9d?s=500',
#    'subcol': 1,
#    'time': '13:15',
#    'title': 'Understanding of distributed processing in Python',
#    'track': 1},
#   {'bio': '<p>My name is Jiranun Jiratrakanvong. You can call me <strong>"Jiranun"</strong>.</p>\n<p>I have been fascinated in computer programming since I was a little. As a kid, my goal was just to make a game bot (Ragnarok) because I was too lazy to play it myself. After studying for many years, I become more lazy to do things and tried to solve everything by programming.</p>\n<p>Python is my beloved language as it\'s easy to use, and it\'s easy to connect to other stuffs</p>\n<p>## Education\n- Undergrad Student at Department of Computer Science, Chulalongkorn University\n- Graduate Student at Department of Computer Science, Illinois Institute of Technology\n- Specializations at IIT: Computational Intelligence, and Data Analytics</p>\n<p>## Experience\n- Software Engineer (C++/Java) at Thomson Reuters/Refinitiv (Bangkok)\n- Python Experience: Research Associate at BioCAT (Chicago)\n- Present: Data Scientist at Coraline (Bangkok)\n- Python Libraries Used: scikit-learn, pandas, numpy, scipy, opencv, PIL, matplotlib, PyQt, Django, Flask, wxPython, reportlab, Cython, numba, fabio, lmfit, pymysql, SQLAlchemy, etc.</p>\n<p>## Hobbies\n- Singing and playing guitar\n- Running (mini marathon)\n- Scuba Diving\n- Traveling</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': "If you think about a Data Science Project, what are you thinking about? Machine learning? Deep learning? AI? Correct! But it’s usually ~20% of the whole project. Let's forget about ML, and I will tell you what we have faced as a Data Science Company, and how we use Python to solve almost everything!",
#    'dur': '00:40',
#    'row': 15,
#    'speaker': 'Jiranun Jiratrakanvong',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/45206/7566C8EA-E7E2-4867-B79A-094534D151DA.jpeg',
#    'subcol': 2,
#    'time': '13:15',
#    'title': 'Python for Data Science Projects at Coraline',
#    'track': 2},
#   {'bio': '<p>I am always fascinated about programming languages. In particular, I have long advocated for the use of functional programming over object-oriented programming and a declarative style over an imperative one. Despite having used Python heavily since 2013, groking Scala, Haskell and Clojure really changed my style of writing Python code. I would like to share some of my findings and advocate a functional style of programming in Python. My other interests include Bayesian statistics, Monte Carlo methods and high-performance computing.</p>\n<p>I am a co-founder and managing director of Arithmox, a startup offering CTO-as-a-service and growth hacking packages to Indonesian companies. My interest lies in the use of technology and data-driven approaches correctly to drive growth. In a business climate where it is easy to get sucked into the AI hype, I advocate a pragmatic and no-nonsense approach to introducing such technologies into already-running businesses.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'In this talk, I argue that Python is not quite a functional programming language. We draw examples from Haskell and Clojure to highlight the importance of immutability, functional core and reusable data. We look into writing idiomatic Python, whilst enjoying the benefits of functional programming.',
#    'dur': '00:40',
#    'row': 15,
#    'speaker': 'Anthony Khong',
#    'speakerimg': 'https://secure.gravatar.com/avatar/62a12078cfba41bcd8d0886a7a7d3a20?s=500',
#    'subcol': 3,
#    'time': '13:15',
#    'title': 'Functional Programming in Python: Lessons from Haskell and Clojure',
#    'track': 3},
#   {'bio': '<p>Rahul Bhatia is a self-taught Data Scientist and Full-stack Web Developer. I have experience in organizing several talks as a Developer Student Club Lead at our campus, which is an initiative by Google Developers, promoting the developer culture at college campuses throughout several countries through the DSC program. I love sharing knowledge with fellow developers and organizing and delivering technical sessions. I am currently a Data Science Intern at Innovaccer, a healthcare company focused on "Righting the wrongs of healthcare technology"</p>\n<p>I don\'t listen to a lot of pop music but I love rock music. Chester from Linkin Park was my favourite. Apart from that, I am a solo traveller and love wadering at new places.</p>',
#    'col': 2,
#    'colspan': 1,
#    'day': 'sun',
#    'description': "What's the use of machine learning models if we can't interpret them? This session will cover recent model interpretability techniques that are essential for Data Scientist to have in their toolbox. Attendees will learn how to apply these techniques in Python on a real-world data science problem.",
#    'dur': '02:20',
#    'row': 15,
#    'speaker': 'Rahul Bhatia',
#    'speakerimg': 'https://secure.gravatar.com/avatar/e16d4591c7f44180024093015eec7512?s=500',
#    'subcol': 4,
#    'time': '13:15',
#    'title': 'Visualize the Black Box - An introduction to Interpretable Machine Learning',
#    'track': 4}],
#  '13:40': [{'bio': '<p>I love to develop software using Python/Django, and manage e-commerce website in Korea.</p>\n<p>I lived in Thailand for 4 years, and I taught some CS subjects in Naresuan University for 2 years.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'I run my own business using Django/Python in Korea.',
#    'dur': '00:40',
#    'row': 7,
#    'speaker': 'Jonghwa Seo',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/45418/pincoin-logo-A2.png',
#    'subcol': 2,
#    'time': '13:40',
#    'title': 'E-commerce for Django',
#    'track': 2},
#   {'bio': '<ul class="simple">\n<li>Currently, working as a Platform Software Engineer at Bigbasket, India (India\'s largest online food and grocery store).</li>\n<li>MSc in Advanced Computing (Machine Learning, Artifical Intelligence, Robotics, Cloud Computing, and Computational Neuroscience), University of Bristol, United Kingdom.</li>\n<li>International Tech Speaker (spoke at numerous National and International Conferences).</li>\n<li>Last year, gave a talk about "Recurrent Neural Networks and Long Short-Term Memory Networks (LSTMs)" at EuroPython, Edinburgh, Scotland - July 2018.\nLink: <a class="reference external" href="https://ep2018.europython.eu/conference/talks/understanding-and-implementing-recurrent-neural-networks-using-python">Recurrent Neural Networks and Long Short-Term Memory Networks</a>\n</li>\n<li>Last year, gave a talk about "Understanding and Implementing Recurrent Neural Networks using Python" at GeoPython, Basel, Switzerland - May 18.\nLink: <a class="reference external" href="http://2018.geopython.net/#s107">Understanding and Implementing Recurrent Neural Networks using Python</a>\n</li>\n<li>Have 8+ International Publications. [Latest work got published in ACM CHI 2018. The project was exhibited in Montreal, Canada.]</li>\n<li>Received 6 Honours and Awards (International and National level).</li>\n<li>Represented India at International Hackathons like Hack Junction\'16, Finland and Hack the North\'16, Canada. Got invited for more than a ‘dozen\' of prestigious International Hackathons (PennApps\'17, HackNY\'17, Hack Princeton\'17 and many more) and Conferences.</li>\n<li>A Microsoft Certified Professional, Microsoft Technology Associate, IBM Certified Web Developer, and Hewlett Packard Certified Developer.</li>\n<li>Former Software Developer Intern at IBM &amp; an ALL STACK DEVELOPER capable of designing and developing solutions for Mobile, Web, Embedded Systems, and Desktop. Areas of interest are Computational Neuroscience, Deep Learning, and Cloud Computing.</li>\n</ul>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': "Generative Adversarial Networks are one of the latest advancements in Deep Learning. Interested in knowing how to generate content (images, music, and much more) instead of classifying one into categories? Let's dive into the details of GANs: One of the BIGGEST Breakthroughs in the DL Revolution.",
#    'dur': '00:40',
#    'row': 7,
#    'speaker': 'Anmol Krishan Sachdeva',
#    'speakerimg': 'https://secure.gravatar.com/avatar/0233f28830fe1e51ae0b7783e5838db6?s=500',
#    'subcol': 3,
#    'time': '13:40',
#    'title': 'Understanding and Implementing Generative Adversarial Networks (GANs): One of the BIGGEST Breakthroughs in the Deep Learning Revolution',
#    'track': 3},
#   {'col': 2,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'This is a full workshop introducing the concepts of Deep Learning in TensorFlow 2.0 It would give people a set of basic notebooks that they can run in Google Colab outlining the basics of Deep Learning and building models.',
#    'dur': '02:20',
#    'row': 7,
#    'speaker': 'Sam Witteveen + Martin Andrews',
#    'subcol': 4,
#    'time': '13:40',
#    'title': 'Deep Learning Introductory Workshop with TensorFlow 2.0',
#    'track': 4}],
#  '14:05': [{'bio': '<p>Studied Math, building systems, loves traveling and puns.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'Python is now a crucial foundation in our org, with its dynamicity, user friendliness, and community-backed frameworks complementing the firepower we already had from Scala.',
#    'dur': '00:40',
#    'row': 16,
#    'speaker': 'Amir Arad',
#    'speakerimg': 'https://secure.gravatar.com/avatar/7ebded1e9171acbf1b8cbf3532e25172?s=500',
#    'subcol': 1,
#    'time': '14:05',
#    'title': 'From 0 to Awesome: How we got Python to supercharge our ML stack',
#    'track': 1},
#   {'bio': '<p>Rae Knowler is a web developer at Liip in Zürich, where they develop product data APIs and work on Open Data projects. They are interested in the fascinating, comical and sometimes tragic results of attempting to cram the complexity of life and society into computer systems. In their spare time they read a lot of science fiction and hug cats.</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': "We all know we should be writing tests, but coming up with tests for every edge case is hard work and you will inevitably miss some. In this talk, I'll show you how to use Hypothesis in your projects to find more bugs than you would imagine.",
#    'dur': '00:40',
#    'row': 16,
#    'speaker': 'Rae Knowler',
#    'speakerimg': 'https://secure.gravatar.com/avatar/843df29a0383ee0094a5caa2defd8707?s=500',
#    'subcol': 3,
#    'time': '14:05',
#    'title': 'Hypothesis: Property-Based Testing for Python',
#    'track': 3}],
#  '14:55': [{'bio': '<p>I\'m a serial online entrepreneur who is always looking to add useful products to the world  both open source and paid. My standard toolbox includes Python and Django (and sometimes WordPress) on the backend and Vue.js on the frontend. I also do data wrangling and some machine learning in Jupyter, Pandas and Keras.</p>\n<p>My latest startup is a hosted backup service for Borg: <a class="reference external" href="https://www.borgbase.com/">https://www.borgbase.com/</a></p>\n<p>In my spare time I\'m also a Google Summer of Code mentor and maintain various open source projects and standardization efforts:</p>\n<ul class="simple">\n<li>Borg backup client for macOS/Linux: <a class="reference external" href="https://github.com/borgbase/vorta">https://github.com/borgbase/vorta</a>\n</li>\n<li>open source electronic invoicing: <a class="reference external" href="https://www.invoice-x.org/">https://www.invoice-x.org/</a>\n</li>\n<li>invoice2data: extract structured data from PDF invoices <a class="reference external" href="https://github.com/invoice-x/invoice2data">https://github.com/invoice-x/invoice2data</a>\n</li>\n<li>upodder: command line podcast downloader <a class="reference external" href="https://github.com/m3nu/upodder">https://github.com/m3nu/upodder</a>\n</li>\n</ul>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'GraphQL is the new standard for client-server API communication, replacing REST in many newer projects. This talk shows you how to quickly add GraphQL to your Django project, test and use it in a simple Vue.js app. Sample code provided.',
#    'dur': '00:40',
#    'row': 17,
#    'speaker': 'Manuel Riel',
#    'speakerimg': 'https://secure.gravatar.com/avatar/24ba35029a2b10d0af542d213cfdaf3c?s=500',
#    'subcol': 1,
#    'time': '14:55',
#    'title': 'Adding a GraphQL API to Django (with Vue.js frontend)',
#    'track': 1},
#   {'bio': '<dl class="docutils">\n<dt>Dali SOLA is a Data science enthusiast with experience in various aspects of NLP and machine translation.</dt>\n<dd>Dali had an engineer degree from at TEK-UP University in Tunisia and studied two Master degree in\nBusiness Intelligence and Innovation management. His core interest lies in “NLP”, ”Deep learning”,\n“Machine Learning”, ”Machine Translation” and "IA". In 2017 he get rewarded from ATB BANK  for  his solution "smart-HR",\na human resource solution that deal with talents hiring issue, using NLP and IA .</dd>\n</dl>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'With more than 7000 languages spoken across the world, it becomes more and more important to connect people and cultures together; Machine translation shows a real impact at this level.\nThis talk will go through:',
#    'dur': '00:40',
#    'row': 17,
#    'speaker': 'Mohamed Ali SOLA (Dali SOLA)',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/27090/IMG-0002.JPG',
#    'subcol': 2,
#    'time': '14:55',
#    'title': 'Unlocking the power of natural language by machine translation: how python could serve my purpose?',
#    'track': 2},
#   {'bio': "<p>&lt;p&gt;A passionate software developer, Sarthak is a core contributor in Expedia's Mobile Team. He weaves the magic in his code with Python, Java, Kotlin, Scala, C and  JavaScript. Having mastered these languages all by himself, through self projects and open source contributions, he knows what it takes to not just write code but write code that is readable, efficient and maintainable.&lt;/p&gt;</p>\n<blockquote>\n&lt;p&gt;His current adventure involves developing solutions in android ecosystem, internal API(s) and machine learning to help our users have the best experience.&lt;/p&gt;</blockquote>\n<p>Before joining Expedia, he  co-founded one startup in India and did internship at Samsung R&amp;D, Bengaluru. He loves sharing his knowledge and learnings from his adventures in machine learning projects. He has been speaking extensively at internal conferences and now want to spread his knowledge in the open.</p>",
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'Haystack is an Expedia-backed open source distributed tracing project to facilitate detection and remediation of problems in microservices and websites. We will talk about how to set it up on internal infrastructure and monitor micro-services using this with real-time examples.',
#    'dur': '00:40',
#    'row': 17,
#    'speaker': 'Sarthak Deshwal',
#    'speakerimg': 'https://secure.gravatar.com/avatar/ebb0ce50f3e93125e7f5fe4406a78723?s=500',
#    'subcol': 3,
#    'time': '14:55',
#    'title': 'A resilient, scalable tracing and analysis system for micro-services - HayStack',
#    'track': 3}],
#  '15:20': [{'bio': '<p><strong>Nithiroj Tripatarasit</strong></p>\n<p><em>Lifelong learner, tech lover, and deep learning enthusiast.</em></p>\n<p><strong>My works</strong></p>\n<ul class="simple">\n<li><a class="reference external" href="https://itunes.apple.com/th/developer/nithiroj-tripatarasit/id704045425">iOS apps</a></li>\n<li><a class="reference external" href="https://play.google.com/store/apps/developer?id=Neo+Edutainment">Android apps</a></li>\n</ul>\n<p><strong>Experiences:</strong></p>\n<ul class="simple">\n<li><a class="reference external" href="https://medium.com/@nithiroj/facial-keypoints-detection-with-pytorch-86bac79141e4">PyTorch Scholarship to Udacity\'s Deep Learning NanoDegree program (Jan 2019  present)</a></li>\n<li><a class="reference external" href="https://www.fast.ai/2018/08/16/diversity-fellowships/">fast.ai International Fellowship Program (Oct 22 - Dec 12, 2018)</a></li>\n<li><a class="reference external" href="https://drive.google.com/file/d/1AZ9RwZSR0uJU6lIwarD5On4cR_y0KA7_/view?usp=sharing">Data Cafe Fellowship #2 ( Aug - Oct 2018)</a></li>\n<li><a class="reference external" href="https://medium.com/diving-in-deep/logo-detection-using-pytorch-7897d4898211">Speaker of  Logo Detection using PyTorch at PyCon Thailand 2018 (Jun 16  17, 2018)</a></li>\n<li><a class="reference external" href="https://wqu-cert.thedataincubator.com/certificate?key=1820009749491963002">WorldQuant University\'s Introduction to Data Science module  (September 7, 2018)</a></li>\n<li><a class="reference external" href="http://www.fast.ai/2018/01/17/international-spring-2018/">fast.ai International Fellowship Program (Mar 19 - Apr 30, 2018)</a></li>\n<li><a class="reference external" href="https://www.coursera.org/account/accomplishments/specialization/X7TVC4FK8J82">Deep Learning, a 5-course specialization by deeplearning.ai on Coursera. Specialization Certificate earned on March 9, 2018</a></li>\n<li><a class="reference external" href="https://www.coursera.org/account/accomplishments/certificate/3DJQGJEUN2ZH">Machine Learning</a></li>\n<li><a class="reference external" href="https://drive.google.com/file/d/1A0CTi9OCQ9MenLBXZ14bp0K-WsF1JEPt/view?usp=sharing">Deep Learning Workshops by Google Developer Experts</a></li>\n<li><a class="reference external" href="https://drive.google.com/file/d/18ulagdP4U2J8mcAnDZPFuE_nKc9c72Dz/view?usp=sharing">Big Data with Hadoop by DEPA</a></li>\n</ul>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Detecting facial keypoints is a very challenging problem. It can be used as a building block in several application such as tracking faces in images and video, analyzing facial expression, face recognition, etc. This talk will walk you through step by step how to solve this problem with PyTorch.',
#    'dur': '00:40',
#    'row': 8,
#    'speaker': 'Nithiroj Tripatarasit',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/27090/IMG-0002.JPG',
#    'subcol': 3,
#    'time': '15:20',
#    'title': 'Facial Keypoints Detection with PyTorch',
#    'track': 3},
#   {'bio': '<p>I started working as a data scientist in July, 2016. Though I have been using regular expressions to clean data for years, since 1999. I finished an M.Phil in Computer Speech and Language Processing from University of Cambridge, UK.</p>\n<p>My focus now includes 2 topics: Thai NLP and Google Colaboratory for knowledge sharing. My main contributions are for <a class="reference external" href="https://github.com/PyThaiNLP/pythainlp">PyThaiNLP project</a> and Colab notebooks shared on <a class="reference external" href="https://www.facebook.com/groups/colab.thailand/">Colab Thailand Facebook Group</a></p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'Colab or Google Colaboratory is a popular tool to run Jupyter Notebook for free on Google Cloud. This talk will cover some advanced uses of Colab, such as %magic, forms, Python-JavaScript communication, adding a kernel, using conda, displaying map, and using microphone and camera.',
#    'dur': '00:40',
#    'row': 18,
#    'speaker': 'Korakot Chaovavanich',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/25745/fullsizeoutput_b7.jpeg',
#    'subcol': 2,
#    'time': '15:20',
#    'title': 'Advanced Google Colaboratory',
#    'track': 2}],
#  '15:45': [{'bio': "<p>Martin is a Google Developer Expert in Machine Learning based in Singapore - and was doing Neural Networks before the last AI winter...  He's an active contributor in the Singapore data science community, and is the co-host of the Singapore TensorFlow and Deep Learning MeetUp (with now with 3700+ members in Singapore).</p>",
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'This talk aims to cover the "something for beginners" part of our tagline - motivating the building blocks of CNNs, how they are trained, and how the resulting model can be applied to different datasets. Code examples will be provided in Colab notebooks.',
#    'dur': '00:40',
#    'row': 19,
#    'speaker': 'Martin Andrews',
#    'speakerimg': 'https://secure.gravatar.com/avatar/eedd4ff31246cafae4a8ebbf08260159?s=500',
#    'subcol': 1,
#    'time': '15:45',
#    'title': 'First steps in Deep Learning with TensorFlow 2.0 : CNNs',
#    'track': 1},
#   {'bio': "<p>I'm a computer scientist with a passion for programming languages, and have been working as a software engineer in the Infrastructure Team at Facebook London since 2016. I've been working with Python on and off for the past 10 years, but recently it has become an area close to my heart.</p>\n<p>I'm the father of an awesome little dude, husband to an amazing wife, and when I'm not spending time with my family,  work, and open source, I'm a captain of a competitive Overwatch team.</p>\n<p>Ask me about the biggest outage I've ever caused ;) See you at the conference!</p>",
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': 'Are linters telling you how to write code? Stop wasting time and let the computer do the work!',
#    'dur': '00:40',
#    'row': 19,
#    'speaker': 'Zsolt Dollenstein',
#    'speakerimg': 'https://secure.gravatar.com/avatar/c64a6a9dfd72d4d6fe680f9cfbf46f58?s=500',
#    'subcol': 2,
#    'time': '15:45',
#    'title': "Any Code Formatter You Like - As Long As It's Black",
#    'track': 2},
#   {'bio': "<p>My real name is Chanapai Chuadchum my nick name is Korn i was started my work on roobtics since i was 10 on the and i got the thrid place on the competition in Solar innovative contest when i was 11 years old since then i'm dedicated to working on robotics to develop the useful and sophisticated robots to make them life like as most as i can currently i'm studying robotics engineer at the pensylavania university online in Robotics Engineer Master degree\nCurrently i'm trying to make my own company in robotics field to serve humanity as much as possible to eleminate the time that we need to spend on unneccessary thing.</p>",
#    'col': 1,
#    'colspan': 1,
#    'day': 'sun',
#    'description': "This talk is about a project that was designed to test the ML A.I research and robotics opensource. The aim is to improve the robot's ability at human interaction and develop various applications for the robot. Right now this robot is an early protype with limited applications. This project aims to improve the robot's abilities in the near future.",
#    'dur': '00:40',
#    'row': 19,
#    'speaker': 'Chanapai Chuadchum',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/45031/profile.jpg',
#    'subcol': 3,
#    'time': '15:45',
#    'title': 'How to build an open source catbot with Python, a 3D printer and a microcontroller',
#    'track': 3}],
#  '16:10': [{'bio': '<p>Drishti is a Computer Engineer at heart and a technology enthusiast. She loves to use technology to help the less fortunate. She believes in democratizing opportunities and brings knowledge of the latest developments in the fast-moving field of technology to deserving students, and keep them up to date and well-equipped for their respective professional careers.\nShe has spoken at 12+ conferences across the globe and is also a social entrepreneur. Her non-profit organisation - Samyak Drishti Foundation works in environment, education and healthcare sectors and operates in 10 cities across India.\nIn her spare time, she likes to paint nature, explore new places and anchor live shows</p>',
#    'col': 1,
#    'colspan': 1,
#    'day': 'sat',
#    'description': 'Have you ever thought of using data visualization to represent data; but feel that it is a cumbersome process? Worry not – Orange is here to the rescue!\nCome, dive into the world of this magical open source data mining tool that can also be used as a Python library.\nBeginner friendly!',
#    'dur': '00:40',
#    'row': 9,
#    'speaker': 'Drishti Jain',
#    'speakerimg': 'https://papercallio-production.s3.amazonaws.com/uploads/user/avatar/36129/WhatsApp_Image_2019-04-21_at_8.52.00_PM.jpeg',
#    'subcol': 3,
#    'time': '16:10',
#    'title': 'When life gives you Orange, make data speak volumes!',
#    'track': 3}],
#  '16:35': [{'bio': 'Anyone can signup at registration',
#    'col': 1,
#    'colspan': 2,
#    'day': 'sun',
#    'description': '5 min timed talks by anyone who signs up at registration',
#    'dur': '01:00',
#    'row': 20,
#    'speaker': 'Signup',
#    'speakerimg': None,
#    'subcol': 5,
#    'time': '16:35',
#    'title': 'Lightning Talks',
#    'track': [1, 2, 3, 4]}],
#  '17:00': [{'bio': 'Anyone can signup at registration',
#    'col': 1,
#    'colspan': 2,
#    'day': 'sat',
#    'description': '5 min timed talks by anyone who signs up at registration',
#    'dur': '00:45',
#    'row': 10,
#    'speaker': 'Signup',
#    'speakerimg': None,
#    'subcol': 5,
#    'time': '17:00',
#    'title': 'Lightning Talks',
#    'track': [1, 2, 3, 4]}]}

# %%
#Generate html file
htmlhead = '''
<style>
.grid-container {
	width: 100%;
	display: grid;
	grid-template-columns: 60% auto;
	grid-row-gap: 10px;
}

.timeflex {
	display: flex;
	flex-direction: row;
}

@media screen and (max-width: 500px) /* Mobile */ {
	.timeflex {
		flex-direction: column;
	}
}

.schedule-item-container {
	display:flex;
	flex-direction: column;
}

.schedule-item {
	padding: 5px;
	padding-left: 10px;
	color: white;
	width: calc(100% - 20px);
	margin-bottom: 5px;
}

.schedule-item-1 {
	background-color: darkblue;
}

.schedule-item-2 {
	background-color: darkgreen;
}

.schedule-item-3 {
	background-color: darkred;
}

.schedule-item-5 {
	background-color: gray;
}

.p-5 {
	padding: 5px;
}

.workshop-item {
	grid-column-start:3;
	background-color: purple;
	color: white;
	margin-bottom: 5px;
	padding: 10px;
	margin-right: 5px;
}

.workshop-item .workshop-text {

}

.timetext {
	padding-top: 5px;
	padding-right: 5px;
}
</style>

<meta charset="utf-8">
<meta name="viewport" content="width=device-width, initial-scale=1.0">
'''

with open('schedule_table.html','w') as f:
  f.write('<!doctype html><html><head>'+htmlhead+'</head><body>'+html+'</body></html>')
